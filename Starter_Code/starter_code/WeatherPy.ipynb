# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 624

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&appid={weather_api_key}&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat =city_weather["coord"]["lat"]
        city_lng =city_weather["coord"]["lon"]
        city_max_temp =city_weather["main"]["temp_max"]
        city_humidity =city_weather["main"]["humidity"]
        city_clouds =city_weather["clouds"]["all"]
        city_wind =city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date =city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | san ramon de la nueva oran
# Processing Record 2 of Set 1 | axim
# Processing Record 3 of Set 1 | sultanah
# Processing Record 4 of Set 1 | waitangi
# Processing Record 5 of Set 1 | wailua homesteads
# Processing Record 6 of Set 1 | margaret river
# Processing Record 7 of Set 1 | yellowknife
# Processing Record 8 of Set 1 | karratha
# Processing Record 9 of Set 1 | andergrove
# Processing Record 10 of Set 1 | kapuskasing
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | lebu
# Processing Record 13 of Set 1 | punta del este
# Processing Record 14 of Set 1 | puerto natales
# Processing Record 15 of Set 1 | port alfred
# Processing Record 16 of Set 1 | blackmans bay
# Processing Record 17 of Set 1 | qarqaraly
# Processing Record 18 of Set 1 | renk
# City not found. Skipping...
# Processing Record 19 of Set 1 | adamstown
# Processing Record 20 of Set 1 | onguday
# Processing Record 21 of Set 1 | fort st. john
# Processing Record 22 of Set 1 | bilibino
# Processing Record 23 of Set 1 | klyuchi
# Processing Record 24 of Set 1 | udachny
# Processing Record 25 of Set 1 | cidreira
# Processing Record 26 of Set 1 | edinburgh of the seven seas
# Processing Record 27 of Set 1 | queenstown
# Processing Record 28 of Set 1 | san jose del cabo
# Processing Record 29 of Set 1 | minot
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | vila velha
# Processing Record 32 of Set 1 | puerto ayora
# Processing Record 33 of Set 1 | ungsang-nodongjagu
# Processing Record 34 of Set 1 | iqaluit
# Processing Record 35 of Set 1 | bam
# Processing Record 36 of Set 1 | atafu village
# Processing Record 37 of Set 1 | lozuvatka
# Processing Record 38 of Set 1 | santo antonio
# Processing Record 39 of Set 1 | alo
# Processing Record 40 of Set 1 | letterkenny
# Processing Record 41 of Set 1 | talnakh
# Processing Record 42 of Set 1 | san patricio
# Processing Record 43 of Set 1 | arteche
# Processing Record 44 of Set 1 | akaltara
# Processing Record 45 of Set 1 | kaohsiung
# Processing Record 46 of Set 1 | vadso
# Processing Record 47 of Set 1 | grytviken
# Processing Record 48 of Set 1 | dudinka
# Processing Record 49 of Set 1 | la sarre
# Processing Record 50 of Set 1 | namtsy
# Processing Record 0 of Set 2 | xai-xai
# Processing Record 1 of Set 2 | acarau
# Processing Record 2 of Set 2 | bethel
# Processing Record 3 of Set 2 | anadyr
# Processing Record 4 of Set 2 | undurkhaan
# Processing Record 5 of Set 2 | port-aux-francais
# Processing Record 6 of Set 2 | kodiak
# Processing Record 7 of Set 2 | shinkafi
# Processing Record 8 of Set 2 | uliastay
# Processing Record 9 of Set 2 | papatowai
# Processing Record 10 of Set 2 | labrador city
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | bardai
# Processing Record 13 of Set 2 | whitehorse
# Processing Record 14 of Set 2 | vyerkhnyadzvinsk
# Processing Record 15 of Set 2 | tibiri
# Processing Record 16 of Set 2 | arraial do cabo
# Processing Record 17 of Set 2 | longyearbyen
# Processing Record 18 of Set 2 | khasab
# Processing Record 19 of Set 2 | utrik
# Processing Record 20 of Set 2 | dunedin
# Processing Record 21 of Set 2 | enid
# Processing Record 22 of Set 2 | ushuaia
# Processing Record 23 of Set 2 | dryden
# Processing Record 24 of Set 2 | puerto baquerizo moreno
# Processing Record 25 of Set 2 | saldanha
# Processing Record 26 of Set 2 | hawaiian paradise park
# Processing Record 27 of Set 2 | ust-nera
# Processing Record 28 of Set 2 | daru
# Processing Record 29 of Set 2 | pitanga
# Processing Record 30 of Set 2 | tuy hoa
# Processing Record 31 of Set 2 | sitka
# Processing Record 32 of Set 2 | port lincoln
# Processing Record 33 of Set 2 | vila franca do campo
# Processing Record 34 of Set 2 | carlsbad
# Processing Record 35 of Set 2 | qaqortoq
# Processing Record 36 of Set 2 | west island
# Processing Record 37 of Set 2 | port mathurin
# Processing Record 38 of Set 2 | vung tau
# Processing Record 39 of Set 2 | st. john's
# Processing Record 40 of Set 2 | selebi-phikwe
# Processing Record 41 of Set 2 | holualoa
# Processing Record 42 of Set 2 | enewetak
# Processing Record 43 of Set 2 | thompson
# Processing Record 44 of Set 2 | ghadamis
# Processing Record 45 of Set 2 | nikolayevsk-on-amure
# Processing Record 46 of Set 2 | piti village
# Processing Record 47 of Set 2 | port saint john's
# Processing Record 48 of Set 2 | nova vicosa
# Processing Record 49 of Set 2 | beauvais
# Processing Record 0 of Set 3 | baharly
# Processing Record 1 of Set 3 | port blair
# Processing Record 2 of Set 3 | stanley
# Processing Record 3 of Set 3 | east london
# Processing Record 4 of Set 3 | vorkuta
# Processing Record 5 of Set 3 | fortuna
# Processing Record 6 of Set 3 | praia da vitoria
# Processing Record 7 of Set 3 | bodo
# Processing Record 8 of Set 3 | port elizabeth
# Processing Record 9 of Set 3 | volchikha
# Processing Record 10 of Set 3 | mollendo
# Processing Record 11 of Set 3 | smach mean chey
# City not found. Skipping...
# Processing Record 12 of Set 3 | haizhou
# Processing Record 13 of Set 3 | san jose village
# City not found. Skipping...
# Processing Record 14 of Set 3 | walvis bay
# Processing Record 15 of Set 3 | amuntai
# Processing Record 16 of Set 3 | haiku-pauwela
# Processing Record 17 of Set 3 | ribeira grande
# Processing Record 18 of Set 3 | tindouf
# Processing Record 19 of Set 3 | toga village
# City not found. Skipping...
# Processing Record 20 of Set 3 | miahuatlan de porfirio diaz
# Processing Record 21 of Set 3 | inhambane
# Processing Record 22 of Set 3 | vorgashor
# Processing Record 23 of Set 3 | green river
# Processing Record 24 of Set 3 | mazagao
# Processing Record 25 of Set 3 | querqueville
# Processing Record 26 of Set 3 | tura
# Processing Record 27 of Set 3 | bubaque
# Processing Record 28 of Set 3 | santander
# Processing Record 29 of Set 3 | sant lluis
# Processing Record 30 of Set 3 | waingapu
# Processing Record 31 of Set 3 | waddan
# Processing Record 32 of Set 3 | alice springs
# Processing Record 33 of Set 3 | osorio
# Processing Record 34 of Set 3 | bemidji
# Processing Record 35 of Set 3 | palmer
# Processing Record 36 of Set 3 | howrah
# Processing Record 37 of Set 3 | georgetown
# Processing Record 38 of Set 3 | basco
# Processing Record 39 of Set 3 | bredasdorp
# Processing Record 40 of Set 3 | montevideo
# Processing Record 41 of Set 3 | recani
# Processing Record 42 of Set 3 | ebon
# Processing Record 43 of Set 3 | kidal
# Processing Record 44 of Set 3 | avarua
# Processing Record 45 of Set 3 | coquimbo
# Processing Record 46 of Set 3 | kerikeri
# Processing Record 47 of Set 3 | hayma'
# City not found. Skipping...
# Processing Record 48 of Set 3 | ancud
# Processing Record 49 of Set 3 | uturoa
# Processing Record 0 of Set 4 | tweed heads
# Processing Record 1 of Set 4 | tazovsky
# Processing Record 2 of Set 4 | ilulissat
# Processing Record 3 of Set 4 | olonkinbyen
# Processing Record 4 of Set 4 | ola
# Processing Record 5 of Set 4 | kone
# Processing Record 6 of Set 4 | rundu
# Processing Record 7 of Set 4 | sangueya
# Processing Record 8 of Set 4 | tsiombe
# Processing Record 9 of Set 4 | tateyama
# Processing Record 10 of Set 4 | karasuk
# Processing Record 11 of Set 4 | sechura
# Processing Record 12 of Set 4 | lihue
# Processing Record 13 of Set 4 | qazigund
# Processing Record 14 of Set 4 | piacabucu
# Processing Record 15 of Set 4 | nemuro
# Processing Record 16 of Set 4 | tralee
# Processing Record 17 of Set 4 | hermanus
# Processing Record 18 of Set 4 | isafjordur
# Processing Record 19 of Set 4 | rio grande
# Processing Record 20 of Set 4 | hami
# Processing Record 21 of Set 4 | uporovo
# Processing Record 22 of Set 4 | mahina
# Processing Record 23 of Set 4 | ponta delgada
# Processing Record 24 of Set 4 | taiohae
# City not found. Skipping...
# Processing Record 25 of Set 4 | sao gabriel da cachoeira
# Processing Record 26 of Set 4 | prince rupert
# Processing Record 27 of Set 4 | tranovaho
# City not found. Skipping...
# Processing Record 28 of Set 4 | mount pearl
# Processing Record 29 of Set 4 | djambala
# Processing Record 30 of Set 4 | richards bay
# Processing Record 31 of Set 4 | misliyah
# Processing Record 32 of Set 4 | konarka
# Processing Record 33 of Set 4 | papantla de olarte
# Processing Record 34 of Set 4 | tiksi
# Processing Record 35 of Set 4 | aykhal
# Processing Record 36 of Set 4 | kingston
# Processing Record 37 of Set 4 | hithadhoo
# Processing Record 38 of Set 4 | chipinge
# Processing Record 39 of Set 4 | oranjemund
# Processing Record 40 of Set 4 | egilsstadir
# Processing Record 41 of Set 4 | lincoln city
# Processing Record 42 of Set 4 | tumayr
# Processing Record 43 of Set 4 | grootfontein
# Processing Record 44 of Set 4 | midvagur
# Processing Record 45 of Set 4 | zhezqazghan
# Processing Record 46 of Set 4 | gurupa
# Processing Record 47 of Set 4 | keflavik
# Processing Record 48 of Set 4 | mariinsk
# Processing Record 49 of Set 4 | polyarnyy
# Processing Record 0 of Set 5 | prince george
# Processing Record 1 of Set 5 | kailua-kona
# Processing Record 2 of Set 5 | saint-joseph
# Processing Record 3 of Set 5 | kyaikkami
# Processing Record 4 of Set 5 | malango
# Processing Record 5 of Set 5 | kalymnos
# Processing Record 6 of Set 5 | es castell
# Processing Record 7 of Set 5 | pangody
# Processing Record 8 of Set 5 | vernon
# Processing Record 9 of Set 5 | afaahiti
# Processing Record 10 of Set 5 | talcahuano
# Processing Record 11 of Set 5 | el calafate
# Processing Record 12 of Set 5 | hamilton
# Processing Record 13 of Set 5 | robore
# Processing Record 14 of Set 5 | hadibu
# Processing Record 15 of Set 5 | iskateley
# Processing Record 16 of Set 5 | college
# Processing Record 17 of Set 5 | gagarin
# Processing Record 18 of Set 5 | al minya
# Processing Record 19 of Set 5 | woolgoolga
# Processing Record 20 of Set 5 | pointe aux piments
# Processing Record 21 of Set 5 | sokolka
# Processing Record 22 of Set 5 | puerto rosario
# Processing Record 23 of Set 5 | maxixe
# Processing Record 24 of Set 5 | beloyarskiy
# Processing Record 25 of Set 5 | okha
# Processing Record 26 of Set 5 | morehead city
# Processing Record 27 of Set 5 | auki
# Processing Record 28 of Set 5 | antsiranana
# Processing Record 29 of Set 5 | puerto san carlos
# City not found. Skipping...
# Processing Record 30 of Set 5 | constantia
# Processing Record 31 of Set 5 | talegaon dabhade
# Processing Record 32 of Set 5 | batna
# Processing Record 33 of Set 5 | qui nhon
# Processing Record 34 of Set 5 | yagry
# City not found. Skipping...
# Processing Record 35 of Set 5 | pisco
# Processing Record 36 of Set 5 | locharbriggs
# Processing Record 37 of Set 5 | elliot lake
# Processing Record 38 of Set 5 | callao
# Processing Record 39 of Set 5 | las vegas
# Processing Record 40 of Set 5 | khandyga
# Processing Record 41 of Set 5 | sur
# Processing Record 42 of Set 5 | san juan del sur
# Processing Record 43 of Set 5 | flin flon
# Processing Record 44 of Set 5 | kudahuvadhoo
# Processing Record 45 of Set 5 | baiti
# Processing Record 46 of Set 5 | masterton
# Processing Record 47 of Set 5 | columbia falls
# Processing Record 48 of Set 5 | carutapera
# Processing Record 49 of Set 5 | hosur
# Processing Record 0 of Set 6 | cabo san lucas
# Processing Record 1 of Set 6 | vilyuchinsk
# Processing Record 2 of Set 6 | nafplio
# Processing Record 3 of Set 6 | janeng
# Processing Record 4 of Set 6 | beaufort west
# Processing Record 5 of Set 6 | luderitz
# Processing Record 6 of Set 6 | chake chake
# Processing Record 7 of Set 6 | pestovo
# Processing Record 8 of Set 6 | pacific grove
# Processing Record 9 of Set 6 | cambria
# Processing Record 10 of Set 6 | san pedro pochutla
# Processing Record 11 of Set 6 | devinuwara
# City not found. Skipping...
# Processing Record 12 of Set 6 | pangai
# Processing Record 13 of Set 6 | colonia
# Processing Record 14 of Set 6 | potanino
# Processing Record 15 of Set 6 | talara
# Processing Record 16 of Set 6 | brookings
# Processing Record 17 of Set 6 | rio gallegos
# Processing Record 18 of Set 6 | sao francisco
# Processing Record 19 of Set 6 | pemba
# Processing Record 20 of Set 6 | gamba
# Processing Record 21 of Set 6 | horazdovice
# Processing Record 22 of Set 6 | porto novo
# Processing Record 23 of Set 6 | porkhov
# Processing Record 24 of Set 6 | bom jesus
# Processing Record 25 of Set 6 | kavieng
# Processing Record 26 of Set 6 | dassun
# Processing Record 27 of Set 6 | cartagena del chaira
# Processing Record 28 of Set 6 | samsula-spruce creek
# Processing Record 29 of Set 6 | shetpe
# Processing Record 30 of Set 6 | isle of lewis
# City not found. Skipping...
# Processing Record 31 of Set 6 | kununurra
# Processing Record 32 of Set 6 | huarmey
# Processing Record 33 of Set 6 | waynesville
# Processing Record 34 of Set 6 | robertsport
# Processing Record 35 of Set 6 | lompoc
# Processing Record 36 of Set 6 | al 'aziziyah
# Processing Record 37 of Set 6 | olyokminsk
# Processing Record 38 of Set 6 | sarkand
# Processing Record 39 of Set 6 | padang
# Processing Record 40 of Set 6 | spring creek
# Processing Record 41 of Set 6 | marudi
# City not found. Skipping...
# Processing Record 42 of Set 6 | invercargill
# Processing Record 43 of Set 6 | kingscliff
# Processing Record 44 of Set 6 | umm kaddadah
# Processing Record 45 of Set 6 | minas de marcona
# Processing Record 46 of Set 6 | borzna
# Processing Record 47 of Set 6 | guatrache
# Processing Record 48 of Set 6 | howard springs
# Processing Record 49 of Set 6 | lazaro cardenas
# Processing Record 0 of Set 7 | kulia village
# City not found. Skipping...
# Processing Record 1 of Set 7 | castillos
# Processing Record 2 of Set 7 | katerini
# Processing Record 3 of Set 7 | mali
# Processing Record 4 of Set 7 | sinan
# Processing Record 5 of Set 7 | uacu cungo
# Processing Record 6 of Set 7 | arkhangel'sk
# Processing Record 7 of Set 7 | puerto armuelles
# Processing Record 8 of Set 7 | luau
# Processing Record 9 of Set 7 | buturlinovka
# Processing Record 10 of Set 7 | pale
# Processing Record 11 of Set 7 | turkestan
# Processing Record 12 of Set 7 | taoudenni
# Processing Record 13 of Set 7 | amga
# Processing Record 14 of Set 7 | lobva
# Processing Record 15 of Set 7 | xinyuan
# Processing Record 16 of Set 7 | nuuk
# Processing Record 17 of Set 7 | itoman
# Processing Record 18 of Set 7 | burang
# Processing Record 19 of Set 7 | sokoni
# Processing Record 20 of Set 7 | badger
# Processing Record 21 of Set 7 | naze
# Processing Record 22 of Set 7 | bandarbeyla
# Processing Record 23 of Set 7 | chichiriviche
# Processing Record 24 of Set 7 | lakhipur
# Processing Record 25 of Set 7 | puerto colombia
# Processing Record 26 of Set 7 | kiffa
# Processing Record 27 of Set 7 | we
# City not found. Skipping...
# Processing Record 28 of Set 7 | tual
# Processing Record 29 of Set 7 | montepuez
# Processing Record 30 of Set 7 | shingu
# Processing Record 31 of Set 7 | laguna
# Processing Record 32 of Set 7 | qamdo
# Processing Record 33 of Set 7 | fale old settlement
# Processing Record 34 of Set 7 | caleta olivia
# Processing Record 35 of Set 7 | san jose de feliciano
# Processing Record 36 of Set 7 | san angelo
# Processing Record 37 of Set 7 | laibin
# Processing Record 38 of Set 7 | belyayevka
# Processing Record 39 of Set 7 | petropavlovsk-kamchatsky
# Processing Record 40 of Set 7 | broome
# Processing Record 41 of Set 7 | nogliki
# Processing Record 42 of Set 7 | remire-montjoly
# Processing Record 43 of Set 7 | karpenisi
# Processing Record 44 of Set 7 | tenenkou
# Processing Record 45 of Set 7 | amursk
# Processing Record 46 of Set 7 | camana
# Processing Record 47 of Set 7 | sterling
# Processing Record 48 of Set 7 | ryotsu-minato
# Processing Record 49 of Set 7 | nevel'sk
# Processing Record 0 of Set 8 | kill devil hills
# Processing Record 1 of Set 8 | ves'yegonsk
# Processing Record 2 of Set 8 | grants pass
# Processing Record 3 of Set 8 | new norfolk
# Processing Record 4 of Set 8 | la foa
# Processing Record 5 of Set 8 | palikir - national government center
# Processing Record 6 of Set 8 | tolanaro
# Processing Record 7 of Set 8 | alta
# Processing Record 8 of Set 8 | lagoa
# Processing Record 9 of Set 8 | coahuayana de hidalgo
# Processing Record 10 of Set 8 | saipan
# Processing Record 11 of Set 8 | dalandzadgad
# Processing Record 12 of Set 8 | lembar
# City not found. Skipping...
# Processing Record 13 of Set 8 | aasiaat
# Processing Record 14 of Set 8 | fuerte olimpo
# Processing Record 15 of Set 8 | ipu
# Processing Record 16 of Set 8 | novoagansk
# Processing Record 17 of Set 8 | priozersk
# Processing Record 18 of Set 8 | vingt cinq
# City not found. Skipping...
# Processing Record 19 of Set 8 | baki
# Processing Record 20 of Set 8 | collie
# Processing Record 21 of Set 8 | santa cruz
# Processing Record 22 of Set 8 | cidade velha
# Processing Record 23 of Set 8 | choma
# Processing Record 24 of Set 8 | portland
# Processing Record 25 of Set 8 | chilliwack
# Processing Record 26 of Set 8 | shwebo
# Processing Record 27 of Set 8 | orange beach
# Processing Record 28 of Set 8 | el charco
# Processing Record 29 of Set 8 | hasaki
# Processing Record 30 of Set 8 | timaru
# Processing Record 31 of Set 8 | saudarkrokur
# Processing Record 32 of Set 8 | temirlanovka
# Processing Record 33 of Set 8 | flying fish cove
# Processing Record 34 of Set 8 | la passe
# Processing Record 35 of Set 8 | i-n-salah
# Processing Record 36 of Set 8 | feodosiya
# Processing Record 37 of Set 8 | kourou
# Processing Record 38 of Set 8 | albu kamal
# Processing Record 39 of Set 8 | broadstairs
# Processing Record 40 of Set 8 | yen vinh
# Processing Record 41 of Set 8 | canutama
# Processing Record 42 of Set 8 | paraiso
# Processing Record 43 of Set 8 | qurayyat
# Processing Record 44 of Set 8 | rebola
# Processing Record 45 of Set 8 | vila do maio
# Processing Record 46 of Set 8 | laikit, laikit ii (dimembe)
# Processing Record 47 of Set 8 | nar'yan-mar
# Processing Record 48 of Set 8 | kralendijk
# Processing Record 49 of Set 8 | carnarvon
# Processing Record 0 of Set 9 | inari
# Processing Record 1 of Set 9 | ocean pointe
# City not found. Skipping...
# Processing Record 2 of Set 9 | gevas
# Processing Record 3 of Set 9 | kalmunai
# Processing Record 4 of Set 9 | umba
# Processing Record 5 of Set 9 | ulsteinvik
# Processing Record 6 of Set 9 | cuiaba
# Processing Record 7 of Set 9 | puerto lempira
# Processing Record 8 of Set 9 | kenai
# Processing Record 9 of Set 9 | taishan
# Processing Record 10 of Set 9 | kaa-khem
# Processing Record 11 of Set 9 | aberdeen
# Processing Record 12 of Set 9 | ilha solteira
# Processing Record 13 of Set 9 | bathsheba
# Processing Record 14 of Set 9 | klaksvik
# Processing Record 15 of Set 9 | yecla
# Processing Record 16 of Set 9 | nishinoomote
# Processing Record 17 of Set 9 | dengi
# Processing Record 18 of Set 9 | hengyang
# Processing Record 19 of Set 9 | menderes
# Processing Record 20 of Set 9 | gebeit
# Processing Record 21 of Set 9 | kuala terengganu
# Processing Record 22 of Set 9 | taltal
# Processing Record 23 of Set 9 | dawei
# Processing Record 24 of Set 9 | bonny
# Processing Record 25 of Set 9 | gweru
# Processing Record 26 of Set 9 | barsi
# Processing Record 27 of Set 9 | tari
# Processing Record 28 of Set 9 | katsuura
# Processing Record 29 of Set 9 | nyaunglebin
# Processing Record 30 of Set 9 | al-`ula
# City not found. Skipping...
# Processing Record 31 of Set 9 | kulhudhuffushi
# Processing Record 32 of Set 9 | watseka
# Processing Record 33 of Set 9 | ouesso
# Processing Record 34 of Set 9 | grand falls-windsor
# Processing Record 35 of Set 9 | babana
# Processing Record 36 of Set 9 | wabash
# Processing Record 37 of Set 9 | hat yai
# Processing Record 38 of Set 9 | fort bragg
# Processing Record 39 of Set 9 | sarangani
# Processing Record 40 of Set 9 | luganville
# Processing Record 41 of Set 9 | gashua
# Processing Record 42 of Set 9 | goure
# Processing Record 43 of Set 9 | skowhegan
# Processing Record 44 of Set 9 | penrith
# Processing Record 45 of Set 9 | tobi village
# City not found. Skipping...
# Processing Record 46 of Set 9 | weyburn
# Processing Record 47 of Set 9 | troitskoye
# Processing Record 48 of Set 9 | sisimiut
# Processing Record 49 of Set 9 | attapeu
# Processing Record 0 of Set 10 | sogndal
# Processing Record 1 of Set 10 | southside
# Processing Record 2 of Set 10 | letlhakane
# Processing Record 3 of Set 10 | belo sur tsiribihina
# Processing Record 4 of Set 10 | ha dong
# Processing Record 5 of Set 10 | prado
# Processing Record 6 of Set 10 | pittsburg
# Processing Record 7 of Set 10 | nenjiang
# Processing Record 8 of Set 10 | afua
# Processing Record 9 of Set 10 | aral
# Processing Record 10 of Set 10 | lower hutt
# Processing Record 11 of Set 10 | talne
# City not found. Skipping...
# Processing Record 12 of Set 10 | taslicay
# Processing Record 13 of Set 10 | kaiapoi
# Processing Record 14 of Set 10 | zeya
# Processing Record 15 of Set 10 | tucuma
# Processing Record 16 of Set 10 | pasargad
# City not found. Skipping...
# Processing Record 17 of Set 10 | north platte
# Processing Record 18 of Set 10 | brak
# Processing Record 19 of Set 10 | tevragh zeina
# City not found. Skipping...
# Processing Record 20 of Set 10 | mesyagutovo
# Processing Record 21 of Set 10 | sao tome
# Processing Record 22 of Set 10 | brisas de zicatela
# Processing Record 23 of Set 10 | al bawiti
# Processing Record 24 of Set 10 | tarfaya
# Processing Record 25 of Set 10 | fengrun
# Processing Record 26 of Set 10 | bonthe
# Processing Record 27 of Set 10 | weno
# Processing Record 28 of Set 10 | miyako
# Processing Record 29 of Set 10 | tandil
# Processing Record 30 of Set 10 | dongsheng
# Processing Record 31 of Set 10 | tucurui
# Processing Record 32 of Set 10 | ishigaki
# Processing Record 33 of Set 10 | smithers
# Processing Record 34 of Set 10 | yamada
# Processing Record 35 of Set 10 | ormara
# Processing Record 36 of Set 10 | sorong
# Processing Record 37 of Set 10 | valparaiso
# Processing Record 38 of Set 10 | erseke
# Processing Record 39 of Set 10 | lata
# Processing Record 40 of Set 10 | fuvahmulah
# City not found. Skipping...
# Processing Record 41 of Set 10 | konstantinovka
# Processing Record 42 of Set 10 | kargopol'
# Processing Record 43 of Set 10 | beroroha
# Processing Record 44 of Set 10 | silver springs
# Processing Record 45 of Set 10 | geraldton
# Processing Record 46 of Set 10 | fonte boa
# Processing Record 47 of Set 10 | obidos
# Processing Record 48 of Set 10 | saynshand
# Processing Record 49 of Set 10 | keetmanshoop
# Processing Record 0 of Set 11 | keren
# Processing Record 1 of Set 11 | kamina
# Processing Record 2 of Set 11 | lagunas
# Processing Record 3 of Set 11 | saint-pierre
# Processing Record 4 of Set 11 | qom
# Processing Record 5 of Set 11 | lichinga
# Processing Record 6 of Set 11 | kirakira
# Processing Record 7 of Set 11 | suizhou
# Processing Record 8 of Set 11 | malanje
# Processing Record 9 of Set 11 | northam
# Processing Record 10 of Set 11 | conceicao do araguaia
# Processing Record 11 of Set 11 | singaraja
# Processing Record 12 of Set 11 | fisterra
# Processing Record 13 of Set 11 | ixtapa
# Processing Record 14 of Set 11 | ferkessedougou
# Processing Record 15 of Set 11 | bandar-e genaveh
# Processing Record 16 of Set 11 | boa vista
# Processing Record 17 of Set 11 | crane
# Processing Record 18 of Set 11 | al kharijah
# Processing Record 19 of Set 11 | kapa'a
# Processing Record 20 of Set 11 | alofi
# Processing Record 21 of Set 11 | martakert
# Processing Record 22 of Set 11 | nakambala
# Processing Record 23 of Set 11 | vilyuysk
# Processing Record 24 of Set 11 | castlebar
# Processing Record 25 of Set 11 | mejit
# Processing Record 26 of Set 11 | lospalos
# Processing Record 27 of Set 11 | mulayjah
# Processing Record 28 of Set 11 | kolwezi
# Processing Record 29 of Set 11 | christchurch
# Processing Record 30 of Set 11 | lorengau
# Processing Record 31 of Set 11 | eravur town
# Processing Record 32 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 33 of Set 11 | laishevo
# Processing Record 34 of Set 11 | lyantonde
# Processing Record 35 of Set 11 | mount gambier
# Processing Record 36 of Set 11 | hotan
# Processing Record 37 of Set 11 | atar
# Processing Record 38 of Set 11 | mathba
# Processing Record 39 of Set 11 | kavaratti
# Processing Record 40 of Set 11 | itabira
# Processing Record 41 of Set 11 | altagracia de orituco
# Processing Record 42 of Set 11 | sao vicente
# Processing Record 43 of Set 11 | chonchi
# Processing Record 44 of Set 11 | mahibadhoo
# Processing Record 45 of Set 11 | susuman
# Processing Record 46 of Set 11 | calintaan
# Processing Record 47 of Set 11 | bredy
# Processing Record 48 of Set 11 | mugia
# Processing Record 49 of Set 11 | alaghsas
# Processing Record 0 of Set 12 | n'dalatando
# Processing Record 1 of Set 12 | ilovlya
# Processing Record 2 of Set 12 | camiri
# Processing Record 3 of Set 12 | savino
# Processing Record 4 of Set 12 | siwa oasis
# Processing Record 5 of Set 12 | sao felix do xingu
# Processing Record 6 of Set 12 | gao
# Processing Record 7 of Set 12 | hammerfest
# Processing Record 8 of Set 12 | peace river
# Processing Record 9 of Set 12 | marau
# Processing Record 10 of Set 12 | al qitena
# Processing Record 11 of Set 12 | boali
# Processing Record 12 of Set 12 | tanrake village
# City not found. Skipping...
# Processing Record 13 of Set 12 | morondava
# Processing Record 14 of Set 12 | altamira
# Processing Record 15 of Set 12 | vinchia
# Processing Record 16 of Set 12 | sola
# Processing Record 17 of Set 12 | chibougamau
# Processing Record 18 of Set 12 | besisahar
# Processing Record 19 of Set 12 | tofol
# Processing Record 20 of Set 12 | berlin
# Processing Record 21 of Set 12 | svetlyy
# Processing Record 22 of Set 12 | solnechnyy
# Processing Record 23 of Set 12 | omdurman
# Processing Record 24 of Set 12 | cargados carajos
# City not found. Skipping...
# Processing Record 25 of Set 12 | xining
# Processing Record 26 of Set 12 | lensk
# Processing Record 27 of Set 12 | bikenibeu village
# Processing Record 28 of Set 12 | puerto san jose
# Processing Record 29 of Set 12 | poli
# Processing Record 30 of Set 12 | salalah
# Processing Record 31 of Set 12 | ash shatrah
# Processing Record 32 of Set 12 | korla
# Processing Record 33 of Set 12 | wurtulla
# Processing Record 34 of Set 12 | brokopondo
# Processing Record 35 of Set 12 | hell-ville
# Processing Record 36 of Set 12 | jolo
# Processing Record 37 of Set 12 | shimoda
# Processing Record 38 of Set 12 | san luis
# Processing Record 39 of Set 12 | olinda
# Processing Record 40 of Set 12 | ilhabela
# Processing Record 41 of Set 12 | codrington
# Processing Record 42 of Set 12 | baotou
# Processing Record 43 of Set 12 | belmonte
# Processing Record 44 of Set 12 | yar
# Processing Record 45 of Set 12 | scottburgh
# Processing Record 46 of Set 12 | bartica
# Processing Record 47 of Set 12 | camayenne
# Processing Record 48 of Set 12 | plouzane
# Processing Record 49 of Set 12 | prata
# Processing Record 0 of Set 13 | san-pedro
# Processing Record 1 of Set 13 | mahalapye
# Processing Record 2 of Set 13 | sach'khere
# City not found. Skipping...
# Processing Record 3 of Set 13 | rawlins
# Processing Record 4 of Set 13 | al hindiyah
# Processing Record 5 of Set 13 | cabedelo
# Processing Record 6 of Set 13 | sanctuary point
# Processing Record 7 of Set 13 | katsuren-haebaru
# Processing Record 8 of Set 13 | sandpoint
# Processing Record 9 of Set 13 | mossel bay
# Processing Record 10 of Set 13 | nieuw amsterdam
# Processing Record 11 of Set 13 | soio
# Processing Record 12 of Set 13 | carloforte
# Processing Record 13 of Set 13 | vodnyy
# Processing Record 14 of Set 13 | nova sintra
# Processing Record 15 of Set 13 | yuzhno-kurilsk
# Processing Record 16 of Set 13 | ad-damazin
# Processing Record 17 of Set 13 | san luis ixcan
# Processing Record 18 of Set 13 | villa ocampo
# Processing Record 19 of Set 13 | barysaw
# Processing Record 20 of Set 13 | martuk
# Processing Record 21 of Set 13 | williams lake
# Processing Record 22 of Set 13 | okhotsk
# Processing Record 23 of Set 13 | puerto rico
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          597
# Lat           597
# Lng           597
# Max Temp      597
# Humidity      597
# Cloudiness    597
# Wind Speed    597
# Country       597
# Date          597
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                          City      Lat       Lng  Max Temp  Humidity  \
# 0  san ramon de la nueva oran -23.1322  -64.3260     26.35        33
# 1                        axim   4.8699   -2.2405     23.89        91
# 2                    sultanah  24.4926   39.5857     34.25         9
# 3                    waitangi -43.9535 -176.5597      7.68        92
# 4           wailua homesteads  22.0669 -159.3780     30.44        71
#
#    Cloudiness  Wind Speed Country        Date
# 0           0        0.63      AR  1691358605
# 1          58        2.96      GH  1691358567
# 2           0        1.54      SA  1691358606
# 3         100        0.45      NZ  1691358607
# 4          20        5.66      US  1691358607

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0        san ramon de la nueva oran -23.1322  -64.3260     26.35        33
# 1                              axim   4.8699   -2.2405     23.89        91
# 2                          sultanah  24.4926   39.5857     34.25         9
# 3                          waitangi -43.9535 -176.5597      7.68        92
# 4                 wailua homesteads  22.0669 -159.3780     30.44        71
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                 0        0.63      AR  1691358605
# 1                58        2.96      GH  1691358567
# 2                 0        1.54      SA  1691358606
# 3               100        0.45      NZ  1691358607
# 4                20        5.66      US  1691358607

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
lat=city_data_df['Lat']
temp=city_data_df['Max Temp']
plt.scatter(lat,temp,edgecolors="Black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature(2022-10-18)")
plt.grid()
plt.xlabel("latitude")
plt.ylabel("Max temperature(C)")

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
hum=city_data_df["Humidity"]
plt.scatter(lat,hum,edgecolors="Black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity(2022-10-18)")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
cloud=city_data_df["Cloudiness"]
plt.scatter(lat,cloud,edgecolors="Black")
# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (2022-10-18)")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")


# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
wind=city_data_df["Wind Speed"]
plt.scatter(lat,wind,edgecolors="Black")
# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed(2022-10-18)")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(m/s)")


# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_313472\704778071.py in <module>
#       3
#       4 # Display sample data
# ----> 5 northern_hemi_df.head()
#
# NameError: name 'northern_hemi_df' is not defined

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         new norfolk -42.7826  147.0587     11.72        58          12
# 5             ushuaia -54.8000  -68.3000      8.81        81          75
# 7           carnarvon -24.8667  113.6333     20.02        76           0
# 9        saint-pierre -21.3393   55.4781     22.82        68           0
# 10           colorado -22.8375  -51.9731     20.36        86          96
#
#          Wind Speed Country        Date
# City_ID
# 2              1.34      AU  1666108230
# 5              3.09      AR  1666108231
# 7              7.46      AU  1666108232
# 9              5.14      RE  1666108236
# 10             4.69      BR  1666107965

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.7161472181434118

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.4121057168607245

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.05689741545789598

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.0002808747046324607

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.024026517125811015

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.02056735429994368

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.030396762354449467

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.062239040700515696

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
